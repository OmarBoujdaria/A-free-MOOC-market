# %% [markdown]
# ##### Negative Words

# %% [markdown]
# In this notebook, we maintain a list of topic irrelevant words, that will be used in Topic Detection :

# %%
Negative_keywords = [
    'learning',
    'learn',
    'course',
    'complete',
    'create',
    'free',
    
    'coding',
    'build',
    'scratch',
    'good',
    'bad',
    'preview',
    
    'getting',
    'started',
    'easy',
    'basic',
    'basics',
    'advanced',
    'fundamentals',
    'beginners',
    'total',
    'steps',
    'guide',
    'understand',
    'Definition',
    'Principles',
    'everyday',
    'anyday',
    'hour',
    'step',
    'standard',
    'alongside',
    
    'tutorial',
    'lessons',
    'practical',
    'depth',
    'introduction',
    'introducing',
    'better',
    'theory',
    'pretice',
    'lesson',
    

 'Conclusion',
 'Basics',
 'Course Introduction',
 'Start Here',
 'Project',
 'Collections',
 'Introduction to',
 'Introduction to the Course',
 'The Project',
 'Welcome',
 'The Basics',
 'Solutions',
 'Bonus Material',
 'Basics',
 'Events',
 'Introduction to',
 'Components',
 'Forms',
 'Getting started',
 'solutions',
 'Setup',
 'Introduction to',
 'Learning with',
 'Summary',
 'Introduction and Setup',
 'Course',
 'Mastering first Second third Edition',
 'Overview',
 'Advanced',
 'Installation and Setup',
 'Methods',
 'Basics',
 'Introduction to',
 'Extras',
 'Introduction to',
 'Installation',
 'Mastering',
 'Videos',
 'Introduction Setup',
 'Input',
 'Developing Professional like',
 'Bonus Section',
 'Complete Project',
 'Learning Development',
 'by Example',
 'Course Summary',
 'Solutions',
 'Build',
 'Advanced Topics',
 'Introduction to',
 'Templates',
 'Initial Setup',
 'Course Videos',
 'Resources',
 'Real-World projects',
 'Learn to Code in',
 'Language Basics',
 'Introduction to The Basics',
 'Making from scratch',
 'Fundamentals',
 'Basics',
 'Introduction to',
 'Intermediate Learn by Creating',
 'Projects',
 'Basics',
 'Over practical projects built from scratch for beginners',
 'Intro',
 'Projects',
 'Testing',
 'Environment Setup',
 'Fundamentals',
 'Dive into',
 "Let's Learn",
 'Notifications',
 'Language Fundamentals',
 'Introduction',
 'Getting Started With This Course',
 'Solutions',
 'Course Overview',
 'Advanced with',
 'Advanced',
 'Learn to Code in',
 'BONUS mini course',
 'Some important tags',
 'fundamentals',
 'Mastering',
 'Bonus Lecture',
 'Learning',
 'Basics',
 'Navigation',
 'Modern',
 'Solutions','Part',
 'Directives',
 'Basic',
 'advanced',
 'lesson',
 'essentials',
 'workshop',
 'Fundamentals',
'zero',
'one',
'two',
'three',
'four',
'five',
'six',
'seven',
'eight',
'nine',
'ten']

# %%
preposition = """aboard
about
above
absent
across
cross
after
against
along
alongside
amid
amidst
mid
midst
among
amongst
apropos
apud
around
as
astride
at
atop
ontop
before
behind
below
beneath
beside
besides
between
beyond
but
by
circa
come
despite
down
during
except
for
from
in
inside
into
less
like
minus
near
nearer
nearest
of
off
on
onto
opposite
out
outside
over
past
per
plus
post
pre
pro
save
short
since
than
through
thru
throughout
till
to
toward
towards
under
underneath
unlike
until
up
upon
upside
versus
vs
via
vice
with
within
without""".split('\n')

# %%
Negative_keywords = Negative_keywords + preposition

# %%
len(Negative_keywords)
# Out:
# 243

# %%
Single_words = [ elem.split(' ') for elem in Negative_keywords ]

# %%
flaten = [elem for sublist in Single_words for elem in sublist]

# %%
Negative_Words_Set = list(set(flaten))

# %%
import pickle as pkl
pkl.dump( Negative_Words_Set, open( "Neg_keywords.pkl", "wb" ) )
